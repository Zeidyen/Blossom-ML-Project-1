# %% [markdown]
# ## Preliminary

# %%
# importing required libraries
import seaborn as sbn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Importing Province Population and South Africa CrimeStats datasets into for analysis 

ProvinPop = pd.read_csv('ProvincePopulation.csv')
SA_Crime = pd.read_csv('SouthAfricaCrimeStats_v2.csv')

# %%
# Printing the SouthAfricaCrime dataset
SA_Crime.head()
# Out:
#        Province            Station                           Category  \
# 0  Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1       Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2  Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3    Free State          Park Road  All theft not mentioned elsewhere
# 4       Gauteng   Pretoria Central  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# 1       6093       4602       3761       3610       3267       3037
# 2       5341       6093       6316       6803       6035       5761
# 3       5108       4282       3834       3316       3101       3013
# 4       5099       4536       3309       2694       2616       2606
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0       5285       5937       5600       5335       5176
# ...

# %%
# Printing the Popluation dataset
ProvinPop
# Out:
#         Province  Population    Area  Density
# 0        Gauteng    12272263   18178    675.1
# 1  Kwazulu/Natal    10267300   94361    108.8
# 2     Mpumalanga     4039939   76495     52.8
# 3   Western Cape     5822734  129462     45.0
# 4        Limpopo     5404868  125755     43.0
# 5   Eastern Cape     6562053  168966     38.8
# 6     North West     3509953  104882     33.5
# 7     Free State     2745590  129825     21.1
# 8  Northern Cape     1145861  372889      3.1

# %% [markdown]
# # Question 1

# %% [markdown]
# ##### a) Joining population data with crime statistics table

# %%
# Joining two datasets
JPD_data = pd.merge(ProvinPop, SA_Crime, on='Province')
JPD_data
# Out:
#             Province  Population    Area  Density               Station  \
# 0            Gauteng    12272263   18178    675.1           Jhb Central
# 1            Gauteng    12272263   18178    675.1      Pretoria Central
# 2            Gauteng    12272263   18178    675.1              Brooklyn
# 3            Gauteng    12272263   18178    675.1              Booysens
# 4            Gauteng    12272263   18178    675.1              Hillbrow
# 5            Gauteng    12272263   18178    675.1               Sandton
# 6            Gauteng    12272263   18178    675.1             Sunnyside
# 7            Gauteng    12272263   18178    675.1           Jhb Central
# 8            Gauteng    12272263   18178    675.1             Lyttelton
# 9            Gauteng    12272263   18178    675.1           Jhb Central
# 10           Gauteng    12272263   18178    675.1              Honeydew
# 11           Gauteng    12272263   18178    675.1          Kempton Park
# ...

# %% [markdown]
# #### b) Group by: Province and sum crimes over each year

# %%
# Grouping data set and summing the crimes over each year
clms = [str(year)+'-'+str(year+1) for year in range(2005, 2016)]
Prov_data_province_sum = PPSC_data.groupby(['Province'],sort=False)[clms].agg('sum').reset_index()
Prov_data_province_avg = PPSC_data.groupby(['Province'],sort=False)[clms].agg('mean').reset_index()
Prov_data_province_allcrimes = Prov_data_province_sum.sum(axis=1).reset_index()
Prov_data_province_sum
# Out:
#         Province  2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  \
# 0        Gauteng     654817     639635     615618     638186     640074
# 1  Kwazulu/Natal     345784     343798     328368     340095     349103
# 2     Mpumalanga     134829     131444     125954     131410     128814
# 3   Western Cape     381825     396712     395281     398240     417619
# 4        Limpopo     106983     104857      97166      97565      99610
# 5   Eastern Cape     238977     228884     220813     216658     217230
# 6     North West     118840     112471     112340     117118     115680
# 7     Free State     137987     128227     127955     132335     127512
# 8  Northern Cape      56515      52689      48954      50277      49746
#
#    2010-2011  2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0     609305     577959     584315     636195     637332     622218
# 1     343767     348411     362677     355729     348394     342772
# ...

# %% [markdown]
# #### c) Most dangerous province

# %%
# sorting provinces in ascending order of most dangerous 
Prov_data_province_avg.sort_values(clms, axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last')
# Out:
#         Province   2005-2006   2006-2007   2007-2008   2008-2009   2009-2010  \
# 0        Gauteng  169.597773  165.665631  159.445221  165.290339  165.779332
# 3   Western Cape   94.277778   97.953580   97.600247   98.330864  103.115802
# 1  Kwazulu/Natal   68.853843   68.458383   65.385902   67.721027   69.514735
# 2     Mpumalanga   58.065891   56.608096   54.243755   56.593454   55.475452
# 6     North West   53.676603   50.799910   50.740741   52.898826   52.249322
# 7     Free State   46.460269   43.174074   43.082492   44.557239   42.933333
# 5   Eastern Cape   45.158163   43.250945   41.725813   40.940665   41.048753
# 4        Limpopo   40.023569   39.228208   36.350917   36.500187   37.265245
# 8  Northern Cape   23.001628   21.444444   19.924298   20.462759   20.246642
#
#     2010-2011   2011-2012   2012-2013   2013-2014   2014-2015   2015-2016
# 0  157.810153  149.691531  151.337736  164.774670  165.069153  161.154623
# ...

# %% [markdown]
# #### d) Average crimes per year for all types

# %%
# Ranking average per years 
Avg_crime = combine_datasets.drop(columns=['Area','Density','Population', 'Station']) # allocating column to data 
Avg_crime = New_combine.pivot_table(index="Category") # creating pivot table 
Avg_crime = New_combine.rank(method = 'average', ascending=True) # Using average 
Avg_crime
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                        27.0       27.0
# Arson                                                     6.0        6.0
# Assault with the intent to inflict grievous bod...       25.0       25.0
# Attempted murder                                         11.0       11.0
# Bank robbery                                              2.0        2.0
# Burglary at non-residential premises                     15.0       14.0
# Burglary at residential premises                         26.0       26.0
# Carjacking                                                8.0        8.0
# Commercial crime                                         14.0       15.0
# Common assault                                           24.0       24.0
# Common robbery                                           18.0       18.0
# Driving under the influence of alcohol or drugs          13.0       13.0
# ...

# %% [markdown]
# # Question 2

# %% [markdown]
# #### b) Contast volume vs density of crimes

# %%
Prov_data_province_allcrimes
PP_data_withcrimes=ProvinPop

# %%
PP_data_withcrimes['Crimes'] = [int(i) for i in Prov_data_province_allcrimes[0]]

PP_data_withcrimes['Density'].corr(PP_data_withcrimes['Crimes'])
# Out:
# 0.8026935150103423

# %% [markdown]
# # Question 3

# %%
PP_data_crimetype = PPSC_data.groupby('Category')
PP_data_crimetype.first()
# Out:
#                                                    Province  Population  \
# Category
# All theft not mentioned elsewhere                   Gauteng    12272263
# Arson                                               Gauteng    12272263
# Assault with the intent to inflict grievous bod...  Gauteng    12272263
# Attempted murder                                    Gauteng    12272263
# Bank robbery                                        Gauteng    12272263
# Burglary at non-residential premises                Gauteng    12272263
# Burglary at residential premises                    Gauteng    12272263
# Carjacking                                          Gauteng    12272263
# Commercial crime                                    Gauteng    12272263
# Common assault                                      Gauteng    12272263
# Common robbery                                      Gauteng    12272263
# Driving under the influence of alcohol or drugs     Gauteng    12272263
# ...

# %%
PPSC_data_drugs = PPSC_data.loc[PPSC_data['Category'] == 'Drug-related crime']
PPSC_data_drugs
# Out:
#             Province  Population    Area  Density               Station  \
# 132          Gauteng    12272263   18178    675.1      Pretoria Central
# 288          Gauteng    12272263   18178    675.1           Meadowlands
# 316          Gauteng    12272263   18178    675.1             Sunnyside
# 382          Gauteng    12272263   18178    675.1                Moroka
# 478          Gauteng    12272263   18178    675.1              Mamelodi
# 508          Gauteng    12272263   18178    675.1             Katlehong
# 645          Gauteng    12272263   18178    675.1               Tsakane
# 670          Gauteng    12272263   18178    675.1               Lenasia
# 700          Gauteng    12272263   18178    675.1         Carletonville
# 712          Gauteng    12272263   18178    675.1  Or Tambo Intern Airp
# 725          Gauteng    12272263   18178    675.1              Hillbrow
# 734          Gauteng    12272263   18178    675.1              Mabopane
# ...

# %%
PPSC_data_drugs_province =PPSC_data_drugs.loc[(PPSC_data['2005-2006']>1000) | (PPSC_data['2006-2007']>1000) |(PPSC_data['2007-2008']>1000)|(PPSC_data['2008-2009']>1000)|(PPSC_data['2009-2010']>1000)|(PPSC_data['2010-2011']>1000) |(PPSC_data['2011-2012']>1000)|(PPSC_data['2012-2013']>1000)|(PPSC_data['2013-2014']>1000)|(PPSC_data['2014-2015']>1000)|(PPSC_data['2015-2016']>1000)]
PPSC_data_drugs_province.head()
# Out:
#     Province  Population   Area  Density           Station  \
# 132  Gauteng    12272263  18178    675.1  Pretoria Central
# 288  Gauteng    12272263  18178    675.1       Meadowlands
# 382  Gauteng    12272263  18178    675.1            Moroka
# 508  Gauteng    12272263  18178    675.1         Katlehong
# 725  Gauteng    12272263  18178    675.1          Hillbrow
#
#                Category  2005-2006  2006-2007  2007-2008  2008-2009  \
# 132  Drug-related crime        908        499        693        617
# 288  Drug-related crime        604        124        102         80
# 382  Drug-related crime        509        616        480        400
# 508  Drug-related crime        404        169        192        192
# 725  Drug-related crime        275        303        363        331
#
#      2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  2014-2015  \
# 132        680        629        908       1164       1620       2122
# ...

# %%
PPSC_data_drugs_province =PPSC_data_drugs.loc[(PPSC_data['2005-2006']>0) | (PPSC_data['2006-2007']>0) |(PPSC_data['2007-2008']>0)|(PPSC_data['2008-2009']>0)|(PPSC_data['2009-2010']>0)|(PPSC_data['2010-2011']>0) |(PPSC_data['2011-2012']>0)|(PPSC_data['2012-2013']>0)|(PPSC_data['2013-2014']>0)|(PPSC_data['2014-2015']>0)|(PPSC_data['2015-2016']>0)]
PPSC_data_drugs_province.head()
# Out:
#     Province  Population   Area  Density           Station  \
# 132  Gauteng    12272263  18178    675.1  Pretoria Central
# 288  Gauteng    12272263  18178    675.1       Meadowlands
# 316  Gauteng    12272263  18178    675.1         Sunnyside
# 382  Gauteng    12272263  18178    675.1            Moroka
# 478  Gauteng    12272263  18178    675.1          Mamelodi
#
#                Category  2005-2006  2006-2007  2007-2008  2008-2009  \
# 132  Drug-related crime        908        499        693        617
# 288  Drug-related crime        604        124        102         80
# 316  Drug-related crime        566        664        620        651
# 382  Drug-related crime        509        616        480        400
# 478  Drug-related crime        425        257         86         97
#
#      2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  2014-2015  \
# 132        680        629        908       1164       1620       2122
# ...

# %%
columns = [str(year)+'-'+str(year+1) for year in range(2005, 2016)]
Combined_data_sum = combine_datasets.groupby(['Province'],sort=False)[columns].agg('sum').reset_index()
Data_Province_Allcrimes = Combined_data_sum.sum(axis=1).reset_index()
Data_Province_Allcrimes
# Out:
#    index          0
# 0      0  4792127.0
# 1      1  6855654.0
# 2      2  1397044.0
# 3      3  1255258.0
# 4      4  3808898.0
# 5      5  1370933.0
# 6      6  2370079.0
# 7      7  1201185.0
# 8      8   546262.0

# %%
Data_withcrimes = ProvinPop
Data_withcrimes['Crimes'] = [int(i) for i in Data_Province_Allcrimes[0]]
Data_withcrimes
# Out:
#         Province  Population    Area  Density   Crimes
# 0        Gauteng    12272263   18178    675.1  4792127
# 1  Kwazulu/Natal    10267300   94361    108.8  6855654
# 2     Mpumalanga     4039939   76495     52.8  1397044
# 3   Western Cape     5822734  129462     45.0  1255258
# 4        Limpopo     5404868  125755     43.0  3808898
# 5   Eastern Cape     6562053  168966     38.8  1370933
# 6     North West     3509953  104882     33.5  2370079
# 7     Free State     2745590  129825     21.1  1201185
# 8  Northern Cape     1145861  372889      3.1   546262

# %%
# Province with high crime 
for i in PP_data_withcrimes['Province']:
    print((i,list(PPSC_data['Province']).count(i)))
# Out:
# ('Gauteng', 3861)
# ('Kwazulu/Natal', 5022)
# ('Mpumalanga', 2322)
# ('Western Cape', 4050)
# ('Limpopo', 2673)
# ('Eastern Cape', 5292)
# ('North West', 2214)
# ('Free State', 2970)
# ('Northern Cape', 2457)

# %% [markdown]
# # Question 4

# %% [markdown]
# # Question 5
